# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("student-alcohol-maths.csv")
df.sample(n=10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 70      GP   M   16       U     GT3       T     3     1     other     other
# 98      GP   F   16       U     GT3       T     4     4     other     other
# 101     GP   M   16       U     GT3       T     4     4  services   teacher
# 306     GP   M   20       U     GT3       A     3     2  services     other
# 266     GP   M   17       U     GT3       T     3     1  services     other
# 222     GP   F   16       U     GT3       T     2     3  services   teacher
# 125     GP   M   15       U     GT3       T     3     4  services  services
# 156     GP   M   17       R     LE3       T     1     2     other     other
# 373     MS   F   17       R     GT3       T     1     2     other     other
# 362     MS   F   18       U     GT3       T     3     3  services  services
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (395, 33)

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
num_total = len(df)
num_gp = df["school"].value_counts()["GP"]
num_ms = df["school"].value_counts()["MS"]

print("Total number of student records: ", num_total)
print("Percentage of students from Gabriel Pereira (GP) school: {0:.2%}".format(num_gp / num_total))
print("Percentage of students from Mousinho da Silveira (MS): {0:.2%}%".format(num_ms / num_total))
# Out:
# Total number of student records:  395
# Percentage of students from Gabriel Pereira (GP) school: 88.35%
# Percentage of students from Mousinho da Silveira (MS): 11.65%%

# %%
num_total = len(df)
girls = df["sex"].value_counts()["F"]
boys = df["sex"].value_counts()["M"]

print("% girls in the study: {0:.2%}".format(girls / num_total))
print("% boys in the study: {0:.2%}".format(boys / num_total))
# Out:
# % girls in the study: 52.66%
# % boys in the study: 47.34%

# %%
gp_gender = df[df["school"] == "GP"]["sex"].value_counts()
ms_gender = df[df["school"] == "MS"]["sex"].value_counts()

schools_gender = pd.DataFrame([gp_gender, ms_gender])
schools_gender.index = ["GP", "MS"]
schools_gender.plot(kind="bar")
plt.title("Gender distribution by school")
plt.ylabel("No. of students")
plt.xlabel("Address type (F: female, M: male)")
# Out:
# Text(0.5,0,'Address type (F: female, M: male)')

# %%
df["age"].value_counts().plot(kind="bar")
plt.title("Age of students")
plt.ylabel("No. of students")
plt.xlabel("Ages (in years)")
# Out:
# Text(0.5,0,'Ages (in years)')

# %%
df["address"].value_counts().plot(kind="bar")
plt.title("Urban vs. Rural addresses")
plt.ylabel("No. of students")
plt.xlabel("Address type (U: urban, R: rural)")
# Out:
# Text(0.5,0,'Address type (U: urban, R: rural)')

# %%
address_gp = df[df["school"] == "GP"]["address"].value_counts()
address_ms = df[df["school"] == "MS"]["address"].value_counts()

schools_address = pd.DataFrame([address_gp, address_ms])
schools_address.index = ["GP", "MS"]
schools_address.plot(kind="bar")
plt.title("Urban vs. Rural addresses, by school")
plt.ylabel("No. of students")
plt.xlabel("Address type (U: urban, R: rural)")
# Out:
# Text(0.5,0,'Address type (U: urban, R: rural)')

# %%
df["Walc"].value_counts().plot(kind="bar")
plt.title("Weekend alchol consumption of students")
plt.ylabel("No. of students")
plt.xlabel("Alcohol consumption (1: very low, 5: very high)")
# Out:
# Text(0.5,0,'Alcohol consumption (1: very low, 5: very high)')

# %%
walc_gp = df[df["school"] == "GP"]["Walc"].value_counts()
walc_ms = df[df["school"] == "MS"]["Walc"].value_counts()

schools_walc = pd.DataFrame([walc_gp, walc_ms])
schools_walc.index = ["GP", "MS"]
schools_walc.plot(kind="bar")
plt.title("Weekend alcohol consumption of students, by school")
plt.ylabel("No. of students")
plt.xlabel("Alcohol consumption (1: very low, 5: very high)")
# Out:
# Text(0.5,0,'Alcohol consumption (1: very low, 5: very high)')

# %%
df["Dalc"].value_counts().plot(kind="bar")
plt.title("Workday alchol consumption")
plt.ylabel("No. of students")
plt.xlabel("Alcohol consumption (1: very low, 5: very high)")
# Out:
# Text(0.5,0,'Alcohol consumption (1: very low, 5: very high)')

# %%
dalc_gp = df[df["school"] == "GP"]["Dalc"].value_counts()
dalc_ms = df[df["school"] == "MS"]["Dalc"].value_counts()

schools_dalc = pd.DataFrame([walc_gp, walc_ms])
schools_dalc.index = ["GP", "MS"]
schools_dalc.plot(kind="bar")
plt.title("Workday alcohol consumption of students, by school")
plt.ylabel("No. of students")
plt.xlabel("Alcohol consumption (1: very low, 5: very high)")
# Out:
# Text(0.5,0,'Alcohol consumption (1: very low, 5: very high)')

# %%
df["health"].value_counts().plot(kind="bar")
plt.title("Current health status")
plt.ylabel("No. of students")
plt.xlabel("Status (1: very bad to 5: very good)")
# Out:
# Text(0.5,0,'Status (1: very bad to 5: very good)')

# %%
bins = 10
plt.title("No. of absences from school")
plt.hist(df.absences, bins, edgecolor="black")
plt.ylabel("No. of students")
plt.xlabel("No. of absences")
# Out:
# Text(0.5,0,'No. of absences')

# %%
df["famsize"].value_counts().plot(kind="bar")
plt.title("Family size of students")
plt.ylabel("No. of students")
plt.xlabel("Family size (LE3: <= 3, GT3: > 3)")
# Out:
# Text(0.5,0,'Family size (LE3: <= 3, GT3: > 3)')

# %%
df["Pstatus"].value_counts().plot(kind="bar")
plt.title("Parents cohabitation status")
plt.ylabel("No. of students")
plt.xlabel("Cohabitation status (T: living together, A: living apart)")
# Out:
# Text(0.5,0,'Cohabitation status (T: living together, A: living apart)')

# %%
df["Medu"].value_counts().plot(kind="bar")
plt.title("Mother's education")
plt.ylabel("No. of students")
plt.xlabel("Education (0: none, 1: primary education (4th grade), 2: 5th to 9th grade, 3: secondary education, 4: higher education)")
# Out:
# Text(0.5,0,'Education (0: none, 1: primary education (4th grade), 2: 5th to 9th grade, 3: secondary education, 4: higher education)')

# %%
df["Fedu"].value_counts().plot(kind="bar")
plt.title("Father's education")
plt.ylabel("No. of students")
plt.xlabel("Education (0: none, 1: primary education (4th grade), 2: 5th to 9th grade, 3: secondary education, 4: higher education)")
# Out:
# Text(0.5,0,'Education (0: none, 1: primary education (4th grade), 2: 5th to 9th grade, 3: secondary education, 4: higher education)')

# %%
df["Mjob"].value_counts().plot(kind="bar")
plt.title("Mother's job")
plt.ylabel("No. of students")
plt.xlabel("Job title")
# Out:
# Text(0.5,0,'Job title')

# %%
df["Fjob"].value_counts().plot(kind="bar")
plt.title("Father's job")
plt.ylabel("No. of students")
plt.xlabel("Job title")
# Out:
# Text(0.5,0,'Job title')

# %%
df["reason"].value_counts().plot(kind="bar")
plt.title("Reasons for choice of school")
plt.ylabel("No. of students")
plt.xlabel("Reason")
# Out:
# Text(0.5,0,'Reason')

# %%
df["guardian"].value_counts().plot(kind="bar")
plt.title("Student's guardian")
plt.ylabel("No. of students")
plt.xlabel("Guardian")
# Out:
# Text(0.5,0,'Guardian')

# %%
df["traveltime"].value_counts().plot(kind="bar")
plt.title("Time taken to travel to school")
plt.ylabel("No. of students")
plt.xlabel("Time (1: <15 min, 2: 15 - 30min, 3: 30min - 1hr, 4: >1 hr)")
# Out:
# Text(0.5,0,'Time (1: <15 min, 2: 15 - 30min, 3: 30min - 1hr, 4: >1 hr)')

# %%
df["studytime"].value_counts().plot(kind="bar")
plt.title("Weekly study time")
plt.ylabel("No. of students")
plt.xlabel("Time (1: <2 hrs, 2: 2 - 5 hours, 3: 5 - 10 hours, 4: >10 hours)")
# Out:
# Text(0.5,0,'Time (1: <2 hrs, 2: 2 - 5 hours, 3: 5 - 10 hours, 4: >10 hours)')

# %%
df["failures"].value_counts().plot(kind="bar")
plt.title("No of past class failures")
plt.ylabel("No. of students")
plt.xlabel('Previous class failures')
# Out:
# Text(0.5,0,'Previous class failures')

# %%
df["schoolsup"].value_counts().plot(kind="bar")
plt.title("Extra educational support received at school")
plt.ylabel("No. of students")
# Out:
# Text(0,0.5,'No. of students')

# %%
df["famsup"].value_counts().plot(kind="bar")
plt.title("Family educational support received")
plt.ylabel("No. of students")
# Out:
# Text(0,0.5,'No. of students')

# %%
df["paid"].value_counts().plot(kind="bar")
plt.title("Extra paid classes taken within the course subject")
plt.ylabel("No. of students")
# Out:
# Text(0,0.5,'No. of students')

# %%
df["activities"].value_counts().plot(kind="bar")
plt.title("Extra curricular activities")
plt.ylabel("No. of students")
# Out:
# Text(0,0.5,'No. of students')

# %%
df["nursery"].value_counts().plot(kind="bar")
plt.title("Attendance at nursery school")
plt.ylabel("No. of students")
# Out:
# Text(0,0.5,'No. of students')

# %%
df["higher"].value_counts().plot(kind="bar")
plt.title("Higher education desired")
plt.ylabel("No. of students")
# Out:
# Text(0,0.5,'No. of students')

# %%
df["internet"].value_counts().plot(kind="bar")
plt.title("Availability of internet access at home")
plt.ylabel('No. of students')
# Out:
# Text(0,0.5,'No. of students')

# %%
df["romantic"].value_counts().plot(kind="bar")
plt.title("Involved in a romantic relatioship")
plt.ylabel("No. of students")
# Out:
# Text(0,0.5,'No. of students')

# %%
df["famrel"].value_counts().plot(kind="bar")
plt.title("Quality of family relationships")
plt.ylabel("Quality (1: very bad to 5: excellent)")
# Out:
# Text(0,0.5,'Quality (1: very bad to 5: excellent)')

# %%
df["freetime"].value_counts().plot(kind="bar")
plt.title("How much free time students have after school")
plt.ylabel("Amt. of time (1: very low to 5: very high)")
# Out:
# Text(0,0.5,'Amt. of time (1: very low to 5: very high)')

# %%
df["goout"].value_counts().plot(kind="bar")
plt.title("How often students go out with friends")
plt.ylabel("Frequency (1: very low to 5: very high)")
# Out:
# Text(0,0.5,'Frequency (1: very low to 5: very high)')
